# %%
import matplotlib.pyplot as plt
import pandas as pd

df_iris = pd.read_csv(r"datasetiris\iris.data", header=None, names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
fig = plt.figure(figsize=(8, 6)) # Default size is (6, 4)
fig = plt.figure(dpi=200) # Default dpi is 100 -> it stretches the image preserving the aspect ratio

# %%
fig, ax = plt.subplots(3,2, dpi = 200) # fig is the figure object, ax is the axes object, it is used to create subplots

# %%
fig, ax = plt.subplots(1, 2, dpi = 120)
data = [x**2 for x in range(1,11)]
ax[0].plot(range(len(data)), data)
ax[1].scatter(range(len(data)), data)
