# %%
import pandas as pd

data = pd.read_csv('jobs_sample.csv', index_col=0)
print(len(data))
data = data.dropna()
print(len(data))
# Out:
# 20000
# 15263

# %%
data.head()
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 202217  2329485357093600   2 to 8 Years            BBA   $64K-$117K
# 357636  2413588532843745  4 to 14 Years            PhD    $57K-$98K
# 334165  2853106964652580  4 to 10 Years         B.Tech   $65K-$130K
# 525739  3029827368083194  4 to 15 Years            MCA    $55K-$87K
# 830220   875834340093462  0 to 11 Years         B.Tech   $55K-$100K
#
#          location      Country  latitude  longitude  Work Type  Company Size  \
# 202217   Pristina       Kosovo   42.6026    20.9030  Temporary        133363
# 357636       Bern  Switzerland   46.8182     8.2275     Intern         69176
# 334165  N'Djamena         Chad   15.4542    18.7322   Contract         45076
# 525739    Nairobi        Kenya   -1.2864    36.8172  Full-Time         61435
# 830220     Roseau     Dominica   15.4149   -61.3705   Contract        100929
#
#         ...                                   Responsibilities  \
# ...

# %%
company = data.iloc[:, 21:]
company.head()
print(len(company))
companies = company["Company"].unique()
print(len(companies))
company2 = company.drop_duplicates()
print(len(company2))
company.drop_duplicates(subset ="Company", inplace = True)
print(len(company))
# Out:
# 15263
# 680
# 680
# 680
